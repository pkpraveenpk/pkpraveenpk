# %% [markdown]
# ## Importing neccessary modules

# %%
import re
import pandas as pd

# %% [markdown]
# ## Loading data

# %%
data=pd.read_csv(r"K:\Desktop\NIIT\tables\DS3_C2_S1_Yelp_Data_Practice.csv")
data
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1     ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2     6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3     _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4     6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
# ...                      ...         ...                     ...    ...
# 9995  VY_tvNUCCXGXQeSvJl757Q  2012-07-28  Ubyfp2RSDYW0g7Mbr8N3iA      3
# 9996  EKzMHI1tip8rC1-ZAy64yg  2012-01-18  2XyIOQKbVFb6uXQdJ0RzlQ      4
# 9997  53YGfwmbW73JhFiemNeyzQ  2010-11-16  jyznYkIbpqVmlsZxSDSypA      4
# 9998  9SKdOoDHcFoxK5ZtsgHJoA  2012-12-02  5UKq9WQE1qQbJ0DJbc-B6Q      2
# 9999  pF7uRzygyZsltbmVpjIyvw  2010-10-16  vWSmOhg2ID1MNZHaWapGbA      5
#
#                                                    text    type  \
# ...

# %% [markdown]
# ## Task1

# %%
string_filter=data[(data.text.str.contains('crash')) | (data.text.str.contains('amazing')) | (data.text.str.contains('tasty'))]

# %% [markdown]
# ## Task2

# %%
string_filter[['date','user_id']]
# Out:
#             date                 user_id
# 0     2011-01-26  rLtl8ZkDX5vH5nAx9C3q5Q
# 6     2010-02-12  wFweIWhv2fREZV_dYkz_1g
# 8     2012-08-17  Vh_DlizgGhSqQh4qfZ2h6A
# 12    2010-01-11  UPtysDF6cUDUxq2KY-6Dcg
# 16    2008-10-12  SBbftLzfYYKItOMFwOTIJg
# ...          ...                     ...
# 9966  2012-07-20  iPnpD62l5LUL7WXaI3SJFA
# 9968  2010-06-07  rLtl8ZkDX5vH5nAx9C3q5Q
# 9983  2010-06-06  LaEj3VpQh7bgpAZLzSRRrw
# 9991  2011-12-05  hTau-iNZFwoNsPCaiIUTEA
# 9996  2012-01-18  ROru4uk5SaYc3rg8IU7SQw
#
# [1455 rows x 2 columns]

# %% [markdown]
# ## Task3

# %%
reviews=" ".join(x for x in string_filter.text)

# %%
clean_text=re.sub(r'[^a-zA-Z]+',' ',reviews)

# %% [markdown]
# ## Task4

# %%
t4_data=data[data.text.str.contains('phenomena') | data.text.str.contains('Phenomena')]

# %%
text4=" ".join(i for i in data[data.text.str.contains('phenomena')].text)

# %%
print('Total occurence :',len(re.findall('phenomena',text4)))#/len(text4.split(" "))
print('average occurence :',len(re.findall('phenomena',text4))/len(t4_data))
# Out:
# Total occurence : 55
# average occurence : 1.0185185185185186

# %%
t4_data.mean(numeric_only=True)
# Out:
# stars     4.388889
# cool      1.351852
# useful    2.185185
# funny     1.074074
# dtype: float64

# %%
t4_data[['date']]
# Out:
#             date
# 0     2011-01-26
# 76    2011-06-24
# 123   2010-08-15
# 620   2011-03-25
# 716   2007-04-30
# 989   2011-09-18
# 1098  2009-08-07
# 1249  2011-03-07
# 1297  2009-03-31
# 1476  2011-04-30
# 1881  2012-06-15
# 1884  2012-01-21
# 1967  2010-01-02
# 2226  2009-11-25
# 2278  2012-04-13
# 2311  2010-04-21
# 2350  2009-03-26
# 2415  2011-01-08
# 2544  2012-04-03
# 2635  2012-04-30
# 2853  2012-04-25
# 2860  2010-08-07
# 3220  2011-01-19
# 3232  2010-12-07
# 3283  2010-11-25
# 3478  2012-07-17
# 3554  2008-01-06
# 3685  2009-12-31
# 4200  2011-11-21
# 4261  2007-06-13
# 4342  2011-03-14
# 4848  2011-05-07
# 5415  2008-06-21
# 5458  2009-03-09
# 5622  2011-03-30
# 5904  2011-01-25
# 6034  2012-05-24
# 6120  2011-10-22
# 6280  2010-10-04
# 6643  2010-04-13
# 7354  2011-08-22
# 7533  2011-07-07
# 7595  2010-08-07
# 7939  2009-09-04
# 8066  2008-06-09
# 8124  2011-11-10
# 8274  2009-08-12
# 8295  2008-10-03
# 8666  2010-07-28
# 9207  2010-03-19
# 9450  2012-01-13
# ...

# %% [markdown]
# ## Task5

# %%
reviews_5=" ".join(x for x in data[(data.funny==True) & (data.stars==5)].text)

# %%
reviews_5=clean_text=re.sub(r'[^a-zA-Z]+',' ',reviews_5)

# %%
reviews_5
# Out:
# 'The oldish man who owns the store is as sweet as can be Perhaps sweeter than the cookies or ice cream Here s the lowdown Giant ice cream cookie sandwiches for super cheap The flavor permutations are basically endless I had snickerdoodle with cookies and cream ice cream It was marvelous Un fortunately for me lux is close to my house I walk there nearly every day and am much poorer because of it The coffee and pastries are amazing They always play really great music too Fred M pretty much said what I would say so I won t beat a dead horse I ll add though that they offer a wide variety of deep fried quesadillas Did you catch that DEEP FRIED QUESADILLAS I absolutely love this little spot It s a great little known boutique with incredibly unique gift items that I don t have to drive clear out to Scottsdale to find I ve been shopping at Vignettes for about years Whenever I am in a quandary about what to get someone this is the first place that I head to Mostly it is because of the wide ra
# ...
